# %% [markdown]
# # TextMamba3D — A100 Full Training Pipeline (v4.2)
#
# **Target:** Single A100 40GB (Colab)
# **Architecture:** v4.2 — MultiScalePixelTextAttention (stages 1,2,3) + ForegroundContrastiveLoss + Warmup
# **Baseline:** v4.1 Mean Dice = 83.16% (text) / 83.18% (no-text)
# **Goal:** Foreground-aware contrastive learning makes text guidance measurably beneficial
#
# v4.2 changes vs v4.1:
# - **ForegroundContrastiveLoss**: GT-mask weighted pooling of bottleneck tokens + symmetric InfoNCE
# - **Contrastive warmup**: epochs 0-30 off, 30-60 linear ramp to 0.05, 60+ full weight
# - **text features detached** in contrastive branch to prevent BERT gradient interference
# - **pixel_feat** returned from model for foreground-aware contrastive
# - contrastive_weight: 0.0 → 0.05 (with warmup)
#
# **Training config:**
# - weight_decay: 0.01
# - contrastive_weight: 0.05 (warmup from epoch 30)
# - deep_supervision weights: [0.2, 0.1, 0.05]
# - unfreeze_text_layers: 2

# %% [markdown]
# ## 1. Environment Setup

# %%
# NOTE: If using VS Code Colab plugin, run this cell in Colab web UI first
# After mounting once, Drive stays available for the entire runtime session
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cached to Drive: first run compiles mamba-ssm (~5min), subsequent runs use cached wheels (~30s)
# !nvidia-smi
# !pip install -q --cache-dir=/content/drive/MyDrive/pip_cache mamba-ssm causal-conv1d transformers nibabel tensorboard pyyaml tqdm
# Out:
# Fri Mar 13 11:50:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0             50W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 2. Setup Working Directory & Prepare Data
#
# Clone the TextMamba3D repo (first run only), then extract training data from Drive.
#
# **Prerequisites:** Upload `TextBraTS_data.zip` to Google Drive (`My Drive/TextMamba3D/`).

# %%
import os, shutil

REPO_DIR = '/content/TextMamba3D'
DRIVE_BASE = '/content/drive/MyDrive/TextMamba3D'

# Deploy code from Drive (VS Code plugin only syncs notebook, not source files)
if not os.path.exists(REPO_DIR):
    src = os.path.join(DRIVE_BASE, 'TextMamba3D_code')
    if os.path.exists(src):
        shutil.copytree(src, REPO_DIR)
        print(f'Copied code from {src}')
    else:
        print(f'ERROR: {src} not found on Drive')
else:
    print(f'Repo already exists at {REPO_DIR}')

os.chdir(REPO_DIR)
print(f'Working directory: {os.getcwd()}')
# !ls -la
# Out:
# Copied code from /content/drive/MyDrive/TextMamba3D/TextMamba3D_code
# Working directory: /content/TextMamba3D
# total 100
# drwx------ 7 root root  4096 Mar  7 12:20 .
# drwxr-xr-x 1 root root  4096 Mar 13 11:52 ..
# drwx------ 2 root root  4096 Mar  7 12:21 configs
# drwx------ 2 root root  4096 Mar  7 12:22 data
# -rw------- 1 root root 10375 Mar  7 12:20 evaluate_full.py
# -rw------- 1 root root  7910 Mar  7 12:20 evaluate.py
# -rw------- 1 root root 14296 Mar  7 12:20 inference.py
# drwx------ 2 root root  4096 Mar  7 12:21 losses
# drwx------ 2 root root  4096 Mar  7 12:21 models
# -rw------- 1 root root  3371 Mar  7 12:21 preprocess_data.py
# -rw------- 1 root root  5360 Mar  7 12:20 smoke_test.py
# -rw------- 1 root root 20886 Mar 13 11:36 train.py
# drwx------ 2 root root  4096 Mar  7 12:21 utils

# %%
import pathlib, os

os.chdir(REPO_DIR)
print("=" * 60)
print("v4 Patch: Multi-Scale Fusion + Unfreeze BERT + Bug Fixes")
print("=" * 60)

# --- 0. Ensure MultiScalePixelTextAttention exists in fusion.py ---
fusion_path = pathlib.Path("models/fusion.py")
fusion_text = fusion_path.read_text()
if "MultiScalePixelTextAttention" not in fusion_text:
    fusion_path.write_text(fusion_text + '''


class MultiScalePixelTextAttention(nn.Module):
    """Apply PixelTextCrossAttention at multiple encoder stages."""

    def __init__(self, stage_dims: list[int], text_dim: int, num_heads: int = 4):
        super().__init__()
        self.attns = nn.ModuleList([
            PixelTextCrossAttention(img_dim=dim, text_dim=text_dim, num_heads=num_heads)
            for dim in stage_dims
        ])

    def forward(
        self,
        img_features: list[torch.Tensor],
        text_features: torch.Tensor,
        attention_mask: torch.Tensor | None = None,
    ) -> list[torch.Tensor]:
        return [
            attn(img, text_features, attention_mask)
            for attn, img in zip(self.attns, img_features)
        ]
''')
    print("[0/6] Added MultiScalePixelTextAttention to fusion.py")
else:
    print("[0/6] fusion.py already has MultiScalePixelTextAttention")

# --- 1. models/textmamba3d.py: bottleneck-only -> multi-scale fusion ---
pathlib.Path("models/textmamba3d.py").write_text('''# models/textmamba3d.py
"""Text-guided 3D medical image segmentation with Mamba architecture."""

from typing import Optional

import torch
import torch.nn as nn

from .decoder_3d import MambaDecoder3D
from .encoder_3d import MambaEncoder3D
from .fusion import MultiScalePixelTextAttention
from .text_encoder import TextMambaEncoder


class TextMamba3D(nn.Module):
    """Text-guided 3D medical image segmentation model using Mamba architecture."""

    def __init__(
        self,
        img_size: tuple[int, int, int] = (96, 96, 96),
        in_channels: int = 4,
        out_channels: int = 4,
        embed_dim: int = 96,
        depths: list[int] = [2, 2, 2, 2],
        patch_size: tuple[int, int, int] = (4, 4, 4),
        text_embed_dim: int = 256,
        text_max_len: int = 256,
        text_depth: int = 4,
        d_state: int = 16,
        dropout: float = 0.0,
        use_pretrained_text: bool = True,
        unfreeze_text_layers: int = 0,
        use_checkpoint: bool = False,
        text_model_path: str | None = None,
        deep_supervision: bool = False,
    ) -> None:
        super().__init__()

        self.text_embed_dim = text_embed_dim
        self.text_max_len = text_max_len
        bottleneck_dim = embed_dim * (2 ** (len(depths) - 1))

        self.img_encoder = MambaEncoder3D(
            img_size=img_size,
            in_channels=in_channels,
            embed_dim=embed_dim,
            depths=depths,
            patch_size=patch_size,
            d_state=d_state,
            dropout=dropout,
            use_checkpoint=use_checkpoint,
        )

        self.text_encoder = TextMambaEncoder(
            embed_dim=text_embed_dim,
            max_len=text_max_len,
            depth=text_depth,
            d_state=d_state,
            dropout=dropout,
            use_pretrained=use_pretrained_text,
            unfreeze_last_n=unfreeze_text_layers,
            model_path=text_model_path,
        )

        # Multi-scale cross-attention: text guides skip connections at stages 1,2,3
        # Stage 0 excluded (32K tokens too expensive for cross-attention)
        stage_dims = [embed_dim * (2 ** i) for i in range(1, len(depths))]
        self.multi_scale_attn = MultiScalePixelTextAttention(
            stage_dims=stage_dims,     # [96, 192, 384] for embed_dim=48
            text_dim=text_embed_dim,   # 256
            num_heads=4,               # head_dim varies per stage
        )

        self.decoder = MambaDecoder3D(
            img_size=img_size,
            patch_size=patch_size,
            out_channels=out_channels,
            embed_dim=embed_dim,
            depths=depths,
            d_state=d_state,
            dropout=dropout,
            use_checkpoint=use_checkpoint,
            deep_supervision=deep_supervision,
        )

        self.img_proj = nn.Sequential(
            nn.Linear(bottleneck_dim, text_embed_dim),
            nn.LayerNorm(text_embed_dim),
        )

    def forward(
        self,
        img: torch.Tensor,
        text_ids: Optional[torch.Tensor] = None,
        attention_mask: Optional[torch.Tensor] = None,
        return_features: bool = False,
        use_text: bool = True,
    ) -> torch.Tensor | tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        """
        Forward pass for text-guided 3D segmentation.

        Args:
            img: Input image tensor of shape [B, C, D, H, W]
            text_ids: Text token indices of shape [B, L], optional for inference
            attention_mask: [B, L] mask for text padding (1=valid, 0=pad)
            return_features: Whether to return features for contrastive loss
            use_text: Whether to use text guidance (False for text-free inference)

        Returns:
            Segmentation output [B, out_channels, D, H, W], and optionally
            (img_feat, text_feat) for contrastive loss
        """
        img_features = self.img_encoder(img)

        has_text = use_text and text_ids is not None
        if has_text:
            text_features = self.text_encoder(text_ids, attention_mask)
            # Multi-scale fusion: stages 1,2,3 get text cross-attention
            # Stage 0 stays raw (32K tokens, too expensive for cross-attention)
            fused = self.multi_scale_attn(
                img_features[1:], text_features, attention_mask
            )
            decoder_features = [img_features[0]] + fused
        else:
            # Bypass fusion entirely for text-free path
            decoder_features = img_features

        seg_output = self.decoder(decoder_features)

        if not return_features:
            return seg_output

        if has_text:
            # Contrastive: project fused bottleneck for alignment
            img_global = self.img_proj(decoder_features[-1].mean(dim=1))
            text_global = self.text_encoder.get_global_feature(text_features)
            return seg_output, img_global, text_global
        else:
            # No contrastive on text-free batches
            return seg_output, None, None

    def forward_without_text(self, img: torch.Tensor) -> torch.Tensor:
        """Convenience method for inference without text guidance."""
        return self.forward(img, text_ids=None, use_text=False)
''')
print("[1/6] textmamba3d.py -> v4 multi-scale fusion (stages 1,2,3)")

# --- 2. models/__init__.py (add MultiScalePixelTextAttention export) ---
pathlib.Path("models/__init__.py").write_text(
    "from .mamba_block import ("
    + chr(10) + "    MambaBlock, MambaLayer,"
    + chr(10) + "    BiMambaBlock, BiMambaLayer,"
    + chr(10) + "    CrossScanBiMamba3DBlock, CrossScanBiMamba3DLayer,"
    + chr(10) + ")"
    + chr(10) + "from .encoder_3d import PatchEmbed3D, MambaEncoder3D"
    + chr(10) + "from .text_encoder import TextMambaEncoder"
    + chr(10) + "from .fusion import PixelTextCrossAttention, MultiScalePixelTextAttention, FiLMLayer, MultiScaleFiLM, MambaFusion"
    + chr(10) + "from .decoder_3d import MambaDecoder3D"
    + chr(10) + "from .textmamba3d import TextMamba3D"
    + chr(10)
)
print("[2/6] __init__.py -> added MultiScalePixelTextAttention export")

# --- 3. configs/textbrats_a100.yaml (unfreeze_text_layers: 2) ---
pathlib.Path("configs/textbrats_a100.yaml").write_text(
    "# textbrats_a100.yaml - v4 multi-scale fusion + unfreeze BERT"
    + chr(10) + "# A100 40GB optimized"
    + chr(10) + ""
    + chr(10) + "data:"
    + chr(10) + '  data_dir: "./data/BraTS2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData"'
    + chr(10) + '  dataset_type: "textbrats"'
    + chr(10) + "  patch_size: [128, 128, 128]"
    + chr(10) + "  batch_size: 4"
    + chr(10) + "  num_workers: 4"
    + chr(10) + "  train_ratio: 0.596"
    + chr(10) + "  val_ratio: 0.149"
    + chr(10) + ""
    + chr(10) + "model:"
    + chr(10) + "  img_size: [128, 128, 128]"
    + chr(10) + "  in_channels: 4"
    + chr(10) + "  out_channels: 4"
    + chr(10) + "  embed_dim: 48"
    + chr(10) + "  depths: [2, 2, 2, 2]"
    + chr(10) + "  dropout: 0.1"
    + chr(10) + "  text_embed_dim: 256"
    + chr(10) + "  text_max_len: 256"
    + chr(10) + "  use_pretrained_text: true"
    + chr(10) + "  unfreeze_text_layers: 2        # Unfreeze last 2 BERT layers"
    + chr(10) + "  text_model_path: null"
    + chr(10) + ""
    + chr(10) + "loss:"
    + chr(10) + "  dice_weight: 1.0"
    + chr(10) + "  ce_weight: 1.0"
    + chr(10) + "  edge_weight: 1.0"
    + chr(10) + "  contrastive_weight: 0.0"
    + chr(10) + "  temperature: 0.07"
    + chr(10) + "  class_weights: [0.25, 3.0, 1.0, 4.0]"
    + chr(10) + ""
    + chr(10) + "augmentation:"
    + chr(10) + "  use_elastic: true"
    + chr(10) + "  use_modality_dropout: true"
    + chr(10) + ""
    + chr(10) + "training:"
    + chr(10) + "  epochs: 200"
    + chr(10) + "  lr: 0.0001"
    + chr(10) + "  weight_decay: 0.01"
    + chr(10) + "  warmup_epochs: 10"
    + chr(10) + "  patience: 40"
    + chr(10) + "  gradient_accumulation: 1"
    + chr(10) + "  gradient_checkpointing: true"
    + chr(10) + "  deep_supervision: true"
    + chr(10) + "  ds_weights: [0.2, 0.1, 0.05]"
    + chr(10) + "  use_amp: true"
    + chr(10) + "  no_text_ratio: 0.15"
    + chr(10) + "  gradient_clip_norm: 1.0"
    + chr(10) + ""
    + chr(10) + "eval:"
    + chr(10) + '  metrics: ["dice", "hd95"]'
    + chr(10) + "  sliding_window: true"
    + chr(10) + "  sw_overlap: 0.5"
    + chr(10) + "  sw_batch_size: 2"
    + chr(10) + ""
    + chr(10) + "experiment:"
    + chr(10) + '  name: "TextMamba3D_A100_v4_multiscale"'
    + chr(10) + '  description: "v4: multi-scale text fusion (stages 1,2,3) + unfreeze BERT last 2 layers"'
    + chr(10)
)
print("[3/6] textbrats_a100.yaml -> unfreeze_text_layers: 2, v4 experiment name")

# --- 4-6. PyTorch 2.6 weights_only=False fix ---
patched = []
for fname in ["evaluate_full.py", "train.py", "inference.py"]:
    p = pathlib.Path(fname)
    lines = p.read_text().splitlines(True)
    new_lines = []
    changed = False
    for line in lines:
        if "torch.load(" in line and "weights_only" not in line and ")" in line:
            idx = line.rindex(")")
            line = line[:idx] + ", weights_only=False" + line[idx:]
            changed = True
        new_lines.append(line)
    if changed:
        p.write_text("".join(new_lines))
        patched.append(fname)
if patched:
    print("[4-6/6] weights_only=False fix: " + ", ".join(patched))
else:
    print("[4-6/6] weights_only already set in all files")

print()
print("All v4 patches applied successfully!")
print("Expected: ~38M trainable params (vs 24M in v3)")
print("Key changes:")
print("  - Multi-scale text fusion at encoder stages 1,2,3")
print("  - PubMedBERT last 2 layers unfrozen")
print("  - PyTorch 2.6 weights_only compatibility")

# ================================================================
# v4.2 Patch: ForegroundContrastiveLoss + Warmup
# ================================================================
# Drive's TextMamba3D_code already contains V4.2 code (train.py,
# losses/__init__.py, losses/contrastive_loss.py). These checks
# verify the code is correct and apply patches if needed.
print()
print("=" * 60)
print("v4.2 Patch: ForegroundContrastiveLoss + Contrastive Warmup")
print("=" * 60)

# --- v4.2-1: Verify ForegroundContrastiveLoss in contrastive_loss.py ---
cl_path = pathlib.Path("losses/contrastive_loss.py")
cl_text = cl_path.read_text()
if "ForegroundContrastiveLoss" in cl_text:
    print("[v4.2-1] contrastive_loss.py OK (ForegroundContrastiveLoss present)")
else:
    print("[v4.2-1] ERROR: ForegroundContrastiveLoss missing! Update TextMamba3D_code on Drive.")

# --- v4.2-2: Verify losses/__init__.py has fg_contrastive support ---
init_path = pathlib.Path("losses/__init__.py")
init_text = init_path.read_text()
if "ForegroundContrastiveLoss" in init_text and "pixel_feat" in init_text:
    print("[v4.2-2] losses/__init__.py OK (ForegroundContrastiveLoss + pixel_feat)")
else:
    print("[v4.2-2] ERROR: losses/__init__.py missing V4.2 changes! Update TextMamba3D_code on Drive.")

# --- v4.2-3: Patch textmamba3d.py to return pixel_feat (4-tuple) ---
# Step [1/6] above writes V4 code (3-tuple), so we always need to patch to 4-tuple
tm_path = pathlib.Path("models/textmamba3d.py")
tm_text = tm_path.read_text()
if "pixel_feat" not in tm_text:
    tm_text = tm_text.replace(
        "return seg_output, img_global, text_global",
        "pixel_feat = decoder_features[-1]  # bottleneck tokens [B, 64, 384]\n"
        "            return seg_output, img_global, text_global, pixel_feat",
    )
    tm_text = tm_text.replace(
        "return seg_output, None, None",
        "return seg_output, None, None, None",
    )
    tm_path.write_text(tm_text)
    print("[v4.2-3] Patched textmamba3d.py to return pixel_feat (4-tuple)")
else:
    print("[v4.2-3] textmamba3d.py OK (pixel_feat already present)")

# --- v4.2-4: Verify train.py has V4.2 changes ---
train_path = pathlib.Path("train.py")
train_text = train_path.read_text()
checks = {
    "4-tuple unpack": "pixel_feat = model" in train_text or "text_feat, pixel_feat" in train_text,
    "contrastive warmup": "contrastive_warmup" in train_text,
    "pixel_feat in criterion": "pixel_feat=pixel_feat" in train_text,
    "--max-epochs arg": "max-epochs" in train_text or "max_epochs" in train_text,
}
all_ok = all(checks.values())
if all_ok:
    print("[v4.2-4] train.py OK (all V4.2 changes present)")
else:
    missing = [k for k, v in checks.items() if not v]
    print(f"[v4.2-4] ERROR: train.py missing: {', '.join(missing)}")
    print("         Update TextMamba3D_code/train.py on Drive!")

# --- v4.2-5: Update config ---
cfg_path = pathlib.Path("configs/textbrats_a100.yaml")
cfg_text = cfg_path.read_text()
cfg_changed = False
if "contrastive_weight: 0.0" in cfg_text:
    cfg_text = cfg_text.replace("contrastive_weight: 0.0", "contrastive_weight: 0.05")
    cfg_changed = True
if "contrastive_warmup_epochs" not in cfg_text:
    cfg_text = cfg_text.replace(
        "patience: 40",
        "patience: 40\n  contrastive_warmup_epochs: 30",
    )
    cfg_changed = True
if 'name: "TextMamba3D_A100_v4' in cfg_text and "v4.2" not in cfg_text:
    import re
    cfg_text = re.sub(
        r'name: "TextMamba3D_A100_v4[^"]*"',
        'name: "TextMamba3D_A100_v4.2_fg_contrastive"',
        cfg_text,
    )
    cfg_changed = True
if cfg_changed:
    cfg_path.write_text(cfg_text)
    print("[v4.2-5] Updated configs/textbrats_a100.yaml for v4.2")
else:
    print("[v4.2-5] Config already up to date")

print()
print("v4.2 patch complete!")
# Out:
# ============================================================
# v4 Patch: Multi-Scale Fusion + Unfreeze BERT + Bug Fixes
# ============================================================
# [0/6] fusion.py already has MultiScalePixelTextAttention
# [1/6] textmamba3d.py -> v4 multi-scale fusion (stages 1,2,3)
# [2/6] __init__.py -> added MultiScalePixelTextAttention export
# [3/6] textbrats_a100.yaml -> unfreeze_text_layers: 2, v4 experiment name
# [4-6/6] weights_only=False fix: evaluate_full.py
#
# All v4 patches applied successfully!
# Expected: ~38M trainable params (vs 24M in v3)
# Key changes:
#   - Multi-scale text fusion at encoder stages 1,2,3
#   - PubMedBERT last 2 layers unfrozen
#   - PyTorch 2.6 weights_only compatibility
#
# ============================================================
# v4.2 Patch: ForegroundContrastiveLoss + Contrastive Warmup
# ============================================================
# [v4.2-1] contrastive_loss.py OK (ForegroundContrastiveLoss present)
# [v4.2-2] losses/__init__.py OK (ForegroundContrastiveLoss + pixel_feat)
# [v4.2-3] Patched textmamba3d.py to return pixel_feat (4-tuple)
# [v4.2-4] train.py OK (all V4.2 changes present)
# [v4.2-5] Updated configs/textbrats_a100.yaml for v4.2
#
# v4.2 patch complete!

# %%
import zipfile

# Extract BraTS data from Drive to local /content for fast I/O
DATA_ZIP = os.path.join(DRIVE_BASE, "TextBraTS_data.zip")
DATA_DIR = os.path.join(REPO_DIR, "data/BraTS2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData")

if not os.path.exists(DATA_DIR):
    os.makedirs(os.path.dirname(DATA_DIR), exist_ok=True)
    if os.path.exists(DATA_ZIP):
        print(f"Extracting {DATA_ZIP} ...")
        with zipfile.ZipFile(DATA_ZIP, 'r') as zf:
            zf.extractall(os.path.dirname(DATA_DIR))
        print(f"Done. Cases found: {len(os.listdir(DATA_DIR))}")
    else:
        print(f"ERROR: Data zip not found at {DATA_ZIP}")
        print("Upload TextBraTS_data.zip to Drive/TextMamba3D/")
else:
    print(f"Data already extracted. Cases: {len(os.listdir(DATA_DIR))}")
# Out:
# Extracting /content/drive/MyDrive/TextMamba3D/TextBraTS_data.zip ...
# Done. Cases found: 371

# %% [markdown]
# ## 3. Smoke Test (Quick Sanity Check)
#
# Verify everything works: load model, check param count, run 1 epoch on 10 samples, confirm VRAM usage.

# %%
# Smoke test: 10 samples, vision-only (quick VRAM check for v4.2 architecture)
# !python train.py --config configs/textbrats_a100.yaml --max-samples 10 --no-text-ratio 1.0 --grad-accum 1 --max-epochs 2

# Check peak VRAM (subprocess has separate CUDA context)
# !nvidia-smi --query-gpu=memory.used --format=csv,noheader,nounits
print("(Peak VRAM reported by nvidia-smi after smoke test)")
# Out:
# 2026-03-13 11:54:47.315242: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-13 11:54:47.332703: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773402887.354659    3024 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773402887.361911    3024 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773402887.380488    3024 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773402887.380515    3024 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773402887.380518    3024 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773402887.380521    3024 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-13 11:54:47.385217: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
# Mixed precision (AMP): True
# No-text training ratio: 1.0
# Gradient accumulation: 1
# Loading PubMedBERT tokenizer: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# config.json: 100% 385/385 [00:00<00:00, 2.36MB/s]
# tokenizer_config.json: 100% 28.0/28.0 [00:00<00:00, 160kB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 226kB [00:00, 47.1MB/s]
# Using TextBraTS dataset (expert-annotated text)
# TextBraTS train: 219 samples
# TextBraTS val: 54 samples
# Limited training to 10 samples
# Train samples: 10, Val samples: 54
# Gradient checkpointing: ENABLED (saves ~30-50% GPU memory)
# Deep supervision: ENABLED (aux heads at intermediate decoder stages)
# pytorch_model.bin: 100% 440M/440M [00:03<00:00, 120MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 1131.26it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Trainable parameters: 36,130,208
# Class weights: [0.25, 3.0, 1.0, 4.0]
# Epoch 0: 100% 3/3 [00:09<00:00,  3.11s/it, loss=3.1617, text=N]
# Epoch 0: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.16it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 0: train_loss=3.1809
#   With text:    val_loss=2.3408, val_dice=0.0423
#   Without text: val_loss=2.3408, val_dice=0.0423
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.0423
#   -> New best (with-text): 0.0423
# Epoch 1: 100% 3/3 [00:06<00:00,  2.20s/it, loss=3.0475, text=N]
# Epoch 1: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 1: train_loss=3.1043
#   With text:    val_loss=2.3390, val_dice=0.0426
#   Without text: val_loss=2.3390, val_dice=0.0426
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.0426
#   -> New best (with-text): 0.0426
#
# Training complete!
# Best Dice (with text): 0.0426
# Best Dice (no text):   0.0426
# 0
# (Peak VRAM reported by nvidia-smi after smoke test)

# %% [markdown]
# ## 4. Training
#
# **Strategy:** Single training run with `no_text_ratio=0.15` (85% with-text, 15% without).
# Evaluation compares both modes from the same checkpoint — no separate vision-only run needed.
#
# v4 architecture ensures clean comparison:
# - **with-text:** MultiScalePixelTextAttention fuses image features at stages 1,2,3 with text
# - **no-text:** fusion completely bypassed, raw encoder features pass to decoder

# %%
# Auto-save checkpoints to Drive every N epochs
DRIVE_CKPT = os.path.join(DRIVE_BASE, "checkpoints")
os.makedirs(DRIVE_CKPT, exist_ok=True)

def sync_checkpoints_to_drive():
    """Copy latest checkpoints to Drive for persistence."""
    import glob
    local_ckpt = os.path.join(REPO_DIR, "checkpoints")
    if not os.path.exists(local_ckpt):
        return
    for f in glob.glob(os.path.join(local_ckpt, "*.pth")):
        dst = os.path.join(DRIVE_CKPT, os.path.basename(f))
        shutil.copy2(f, dst)
    print(f"Synced checkpoints to {DRIVE_CKPT}")

print(f"Drive checkpoint dir: {DRIVE_CKPT}")
# Out:
# Drive checkpoint dir: /content/drive/MyDrive/TextMamba3D/checkpoints

# %% [markdown]
# ### Training: v4.2 ForegroundContrastiveLoss + Warmup
#
# **v4.2 architecture:** MultiScalePixelTextAttention at stages 1,2,3 + ForegroundContrastiveLoss + PubMedBERT last 2 layers unfrozen.
# 85% batches use text (multi-scale cross-attention active), 15% without text (fusion bypassed).
# Single run produces both with-text and no-text evaluation from same checkpoint.
#
# **v4.2 key changes:**
# - ForegroundContrastiveLoss: GT-mask weighted pooling of bottleneck tokens + symmetric InfoNCE
# - Contrastive warmup: epochs 0-30 off, 30-60 linear ramp to 0.05, 60+ full weight
# - Text features detached in contrastive branch
# - pixel_feat (bottleneck tokens) returned from model
#
# **Note:** v4.2 checkpoint incompatible with v4.1 (new contrastive projector params) — must train from scratch.

# %%
os.chdir(REPO_DIR)
os.environ["DRIVE_CKPT_DIR"] = DRIVE_CKPT

# Clean previous checkpoints to avoid loading V4.1 weights
import glob
for f in glob.glob(os.path.join(REPO_DIR, "checkpoints/*.pth")):
    os.remove(f)
# Also clean Drive generic checkpoints (V4.2 incompatible with V4.1)
for f in glob.glob(os.path.join(DRIVE_CKPT, "best.pth")) + glob.glob(os.path.join(DRIVE_CKPT, "last.pth")) + glob.glob(os.path.join(DRIVE_CKPT, "best_no_text.pth")):
    os.remove(f)
    print(f"Removed old checkpoint: {f}")

# v4.2 training: MultiScale fusion + ForegroundContrastiveLoss + warmup
# no_text_ratio=0.15: 85% with-text, 15% text-free (fusion bypassed)
# !python train.py \
    --config configs/textbrats_a100.yaml \
    --no-text-ratio 0.15 \
    --grad-accum 1

# Sync and save
sync_checkpoints_to_drive()

best_ckpt = os.path.join(DRIVE_CKPT, "best_v4.2.pth")
local_best = os.path.join(REPO_DIR, "checkpoints/best.pth")
if os.path.exists(local_best):
    shutil.copy2(local_best, best_ckpt)
    print(f"Best checkpoint saved: {best_ckpt}")
# Out:
# Removed old checkpoint: /content/drive/MyDrive/TextMamba3D/checkpoints/best.pth
# Removed old checkpoint: /content/drive/MyDrive/TextMamba3D/checkpoints/last.pth
# Removed old checkpoint: /content/drive/MyDrive/TextMamba3D/checkpoints/best_no_text.pth
# 2026-03-13 11:56:34.961673: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-13 11:56:34.980163: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773402995.002259    3934 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773402995.009647    3934 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773402995.028424    3934 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773402995.028453    3934 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773402995.028456    3934 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773402995.028458    3934 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-13 11:56:35.033360: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
# Mixed precision (AMP): True
# No-text training ratio: 0.15
# Gradient accumulation: 1
# Loading PubMedBERT tokenizer: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Using TextBraTS dataset (expert-annotated text)
# TextBraTS train: 219 samples
# TextBraTS val: 54 samples
# Train samples: 219, Val samples: 54
# Gradient checkpointing: ENABLED (saves ~30-50% GPU memory)
# Deep supervision: ENABLED (aux heads at intermediate decoder stages)
# Loading weights: 100% 199/199 [00:00<00:00, 1429.19it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Trainable parameters: 36,130,208
# Class weights: [0.25, 3.0, 1.0, 4.0]
# Epoch 0: 100% 55/55 [01:13<00:00,  1.34s/it, loss=2.9440, text=Y]
# Epoch 0: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 0: train_loss=3.0902
#   With text:    val_loss=2.4349, val_dice=0.0447
#   Without text: val_loss=2.4352, val_dice=0.0447
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.0447
#   -> New best (with-text): 0.0447
# Epoch 1: 100% 55/55 [01:15<00:00,  1.38s/it, loss=2.8279, text=Y]
# Epoch 1: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 1: train_loss=2.8958
#   With text:    val_loss=2.3670, val_dice=0.0532
#   Without text: val_loss=2.3711, val_dice=0.0529
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.0529
#   -> New best (with-text): 0.0532
# Epoch 2: 100% 55/55 [01:12<00:00,  1.32s/it, loss=2.5539, text=Y]
# Epoch 2: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.17it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 2: train_loss=2.7236
#   With text:    val_loss=2.1619, val_dice=0.1153
#   Without text: val_loss=2.1724, val_dice=0.1096
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.1096
#   -> New best (with-text): 0.1153
# Epoch 3: 100% 55/55 [01:09<00:00,  1.26s/it, loss=2.0423, text=Y]
# Epoch 3: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 3: train_loss=2.3527
#   With text:    val_loss=1.6814, val_dice=0.4535
#   Without text: val_loss=1.6888, val_dice=0.4167
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.4167
#   -> New best (with-text): 0.4535
# Epoch 4: 100% 55/55 [01:09<00:00,  1.27s/it, loss=1.6045, text=Y]
# Epoch 4: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 4: train_loss=1.8105
#   With text:    val_loss=1.2291, val_dice=0.5206
#   Without text: val_loss=1.2301, val_dice=0.5126
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.5126
#   -> New best (with-text): 0.5206
# Epoch 5: 100% 55/55 [01:09<00:00,  1.26s/it, loss=1.9222, text=Y]
# Epoch 5: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 5: train_loss=1.6479
#   With text:    val_loss=1.1637, val_dice=0.5728
#   Without text: val_loss=1.1639, val_dice=0.5708
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.5708
#   -> New best (with-text): 0.5728
# Epoch 6: 100% 55/55 [01:09<00:00,  1.27s/it, loss=1.4483, text=Y]
# Epoch 6: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.30it/s]
# Epoch 6: train_loss=1.5983
#   With text:    val_loss=1.1467, val_dice=0.5392
#   Without text: val_loss=1.1509, val_dice=0.5318
#   Contrastive weight: 0.0000
# Epoch 7: 100% 55/55 [01:08<00:00,  1.25s/it, loss=1.5459, text=N]
# Epoch 7: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:10<00:00,  1.28it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 7: train_loss=1.5148
#   With text:    val_loss=1.0029, val_dice=0.6666
#   Without text: val_loss=1.0052, val_dice=0.6555
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.6555
#   -> New best (with-text): 0.6666
# Epoch 8: 100% 55/55 [01:06<00:00,  1.21s/it, loss=1.4148, text=Y]
# Epoch 8: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 8: train_loss=1.3944
#   With text:    val_loss=0.9023, val_dice=0.6957
#   Without text: val_loss=0.9046, val_dice=0.6902
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.6902
#   -> New best (with-text): 0.6957
# Epoch 9: 100% 55/55 [01:10<00:00,  1.29s/it, loss=1.1689, text=Y]
# Epoch 9: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 9: train_loss=1.2863
#   With text:    val_loss=0.8075, val_dice=0.7383
#   Without text: val_loss=0.8161, val_dice=0.7252
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.7252
#   -> New best (with-text): 0.7383
#   -> Synced checkpoints to Drive (epoch 9)
# Epoch 10: 100% 55/55 [01:15<00:00,  1.37s/it, loss=1.1744, text=Y]
# Epoch 10: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 10: train_loss=1.2614
#   With text:    val_loss=0.7798, val_dice=0.7510
#   Without text: val_loss=0.7739, val_dice=0.7388
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.7388
#   -> New best (with-text): 0.7510
# Epoch 11: 100% 55/55 [01:10<00:00,  1.28s/it, loss=1.5763, text=Y]
# Epoch 11: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 11: train_loss=1.2218
#   With text:    val_loss=0.7367, val_dice=0.7478
#   Without text: val_loss=0.7422, val_dice=0.7386
#   Contrastive weight: 0.0000
# Epoch 12: 100% 55/55 [01:11<00:00,  1.30s/it, loss=1.0673, text=N]
# Epoch 12: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 12: train_loss=1.1508
#   With text:    val_loss=0.6995, val_dice=0.7631
#   Without text: val_loss=0.7012, val_dice=0.7595
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.7595
#   -> New best (with-text): 0.7631
# Epoch 13: 100% 55/55 [01:12<00:00,  1.32s/it, loss=1.1529, text=Y]
# Epoch 13: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 13: train_loss=1.1269
#   With text:    val_loss=0.7365, val_dice=0.7522
#   Without text: val_loss=0.7441, val_dice=0.7482
#   Contrastive weight: 0.0000
# Epoch 14: 100% 55/55 [01:10<00:00,  1.28s/it, loss=1.3482, text=Y]
# Epoch 14: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.27it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 14: train_loss=1.1059
#   With text:    val_loss=0.7089, val_dice=0.7636
#   Without text: val_loss=0.7135, val_dice=0.7616
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.7616
#   -> New best (with-text): 0.7636
# Epoch 15: 100% 55/55 [01:11<00:00,  1.29s/it, loss=1.3432, text=Y]
# Epoch 15: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 15: train_loss=1.0623
#   With text:    val_loss=0.6771, val_dice=0.7775
#   Without text: val_loss=0.6805, val_dice=0.7762
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.7762
#   -> New best (with-text): 0.7775
# Epoch 16: 100% 55/55 [01:08<00:00,  1.24s/it, loss=1.2735, text=Y]
# Epoch 16: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 16: train_loss=1.1076
#   With text:    val_loss=0.6437, val_dice=0.7830
#   Without text: val_loss=0.6424, val_dice=0.7854
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.7854
#   -> New best (with-text): 0.7830
# Epoch 17: 100% 55/55 [01:12<00:00,  1.33s/it, loss=0.9463, text=Y]
# Epoch 17: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 17: train_loss=1.0880
#   With text:    val_loss=0.6465, val_dice=0.7881
#   Without text: val_loss=0.6435, val_dice=0.7891
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.7891
#   -> New best (with-text): 0.7881
# Epoch 18: 100% 55/55 [01:06<00:00,  1.22s/it, loss=0.9214, text=Y]
# Epoch 18: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 18: train_loss=1.0114
#   With text:    val_loss=0.6405, val_dice=0.7807
#   Without text: val_loss=0.6407, val_dice=0.7794
#   Contrastive weight: 0.0000
# Epoch 19: 100% 55/55 [01:12<00:00,  1.31s/it, loss=1.1025, text=N]
# Epoch 19: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 19: train_loss=1.0922
#   With text:    val_loss=0.6261, val_dice=0.8031
#   Without text: val_loss=0.6234, val_dice=0.8034
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.8034
#   -> New best (with-text): 0.8031
#   -> Synced checkpoints to Drive (epoch 19)
# Epoch 20: 100% 55/55 [01:15<00:00,  1.38s/it, loss=1.6015, text=Y]
# Epoch 20: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.23it/s]
# Epoch 20: train_loss=1.0650
#   With text:    val_loss=0.6191, val_dice=0.7857
#   Without text: val_loss=0.6174, val_dice=0.7871
#   Contrastive weight: 0.0000
# Epoch 21: 100% 55/55 [01:08<00:00,  1.24s/it, loss=0.8812, text=Y]
# Epoch 21: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 21: train_loss=1.0223
#   With text:    val_loss=0.5907, val_dice=0.8116
#   Without text: val_loss=0.5911, val_dice=0.8108
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.8108
#   -> New best (with-text): 0.8116
# Epoch 22: 100% 55/55 [01:16<00:00,  1.39s/it, loss=0.9595, text=Y]
# Epoch 22: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.17it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 22: train_loss=0.9843
#   With text:    val_loss=0.6065, val_dice=0.8007
#   Without text: val_loss=0.6086, val_dice=0.7997
#   Contrastive weight: 0.0000
# Epoch 23: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.8779, text=Y]
# Epoch 23: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 23: train_loss=1.0037
#   With text:    val_loss=0.5982, val_dice=0.8101
#   Without text: val_loss=0.5989, val_dice=0.8090
#   Contrastive weight: 0.0000
# Epoch 24: 100% 55/55 [01:08<00:00,  1.25s/it, loss=1.1849, text=N]
# Epoch 24: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 24: train_loss=1.0456
#   With text:    val_loss=0.6483, val_dice=0.7529
#   Without text: val_loss=0.6466, val_dice=0.7543
#   Contrastive weight: 0.0000
# Epoch 25: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.9400, text=Y]
# Epoch 25: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 25: train_loss=1.0020
#   With text:    val_loss=0.6409, val_dice=0.7814
#   Without text: val_loss=0.6403, val_dice=0.7822
#   Contrastive weight: 0.0000
# Epoch 26: 100% 55/55 [01:12<00:00,  1.31s/it, loss=0.8127, text=Y]
# Epoch 26: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:10<00:00,  1.27it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 26: train_loss=0.9690
#   With text:    val_loss=0.5848, val_dice=0.8127
#   Without text: val_loss=0.5857, val_dice=0.8130
#   Contrastive weight: 0.0000
#   -> New best (no-text): 0.8130
#   -> New best (with-text): 0.8127
# Epoch 27: 100% 55/55 [01:11<00:00,  1.30s/it, loss=1.0566, text=Y]
# Epoch 27: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 27: train_loss=0.9959
#   With text:    val_loss=0.5962, val_dice=0.8080
#   Without text: val_loss=0.5950, val_dice=0.8077
#   Contrastive weight: 0.0000
# Epoch 28: 100% 55/55 [01:04<00:00,  1.18s/it, loss=0.8502, text=N]
# Epoch 28: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 28: train_loss=0.9811
#   With text:    val_loss=0.5796, val_dice=0.8006
#   Without text: val_loss=0.5793, val_dice=0.8011
#   Contrastive weight: 0.0000
# Epoch 29: 100% 55/55 [01:10<00:00,  1.28s/it, loss=0.9603, text=Y]
# Epoch 29: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 29: train_loss=0.9617
#   With text:    val_loss=0.5756, val_dice=0.8075
#   Without text: val_loss=0.5761, val_dice=0.8077
#   Contrastive weight: 0.0000
#   -> Synced checkpoints to Drive (epoch 29)
# Epoch 30: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.7752, text=Y]
# Epoch 30: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.30it/s]
# Epoch 30: train_loss=0.9808
#   With text:    val_loss=0.5574, val_dice=0.8064
#   Without text: val_loss=0.5589, val_dice=0.8055
#   Contrastive weight: 0.0000
# Epoch 31: 100% 55/55 [01:10<00:00,  1.28s/it, loss=0.9216, text=Y]
# Epoch 31: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 31: train_loss=0.9344
#   With text:    val_loss=0.5902, val_dice=0.8002
#   Without text: val_loss=0.5924, val_dice=0.7994
#   Contrastive weight: 0.0017
# Epoch 32: 100% 55/55 [01:08<00:00,  1.25s/it, loss=0.8218, text=N]
# Epoch 32: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 32: train_loss=0.9573
#   With text:    val_loss=0.5510, val_dice=0.8233
#   Without text: val_loss=0.5513, val_dice=0.8230
#   Contrastive weight: 0.0033
#   -> New best (no-text): 0.8230
#   -> New best (with-text): 0.8233
# Epoch 33: 100% 55/55 [01:07<00:00,  1.22s/it, loss=0.9544, text=Y]
# Epoch 33: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 33: train_loss=0.9346
#   With text:    val_loss=0.5394, val_dice=0.8246
#   Without text: val_loss=0.5400, val_dice=0.8246
#   Contrastive weight: 0.0050
#   -> New best (no-text): 0.8246
#   -> New best (with-text): 0.8246
# Epoch 34: 100% 55/55 [01:07<00:00,  1.23s/it, loss=1.3848, text=Y]
# Epoch 34: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.15it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 34: train_loss=0.9537
#   With text:    val_loss=0.5343, val_dice=0.8130
#   Without text: val_loss=0.5350, val_dice=0.8126
#   Contrastive weight: 0.0067
# Epoch 35: 100% 55/55 [01:08<00:00,  1.25s/it, loss=0.7176, text=Y]
# Epoch 35: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 35: train_loss=0.9500
#   With text:    val_loss=0.5264, val_dice=0.8153
#   Without text: val_loss=0.5258, val_dice=0.8156
#   Contrastive weight: 0.0083
# Epoch 36: 100% 55/55 [01:09<00:00,  1.27s/it, loss=1.1459, text=Y]
# Epoch 36: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 36: train_loss=0.9355
#   With text:    val_loss=0.5744, val_dice=0.8051
#   Without text: val_loss=0.5747, val_dice=0.8053
#   Contrastive weight: 0.0100
# Epoch 37: 100% 55/55 [01:11<00:00,  1.30s/it, loss=1.3826, text=Y]
# Epoch 37: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 37: train_loss=0.9161
#   With text:    val_loss=0.5172, val_dice=0.8120
#   Without text: val_loss=0.5167, val_dice=0.8126
#   Contrastive weight: 0.0117
# Epoch 38: 100% 55/55 [01:08<00:00,  1.24s/it, loss=1.6741, text=Y]
# Epoch 38: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 38: train_loss=0.9222
#   With text:    val_loss=0.5123, val_dice=0.8359
#   Without text: val_loss=0.5128, val_dice=0.8355
#   Contrastive weight: 0.0133
#   -> New best (no-text): 0.8355
#   -> New best (with-text): 0.8359
# Epoch 39: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.5479, text=Y]
# Epoch 39: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.17it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 39: train_loss=0.8684
#   With text:    val_loss=0.5023, val_dice=0.8321
#   Without text: val_loss=0.5019, val_dice=0.8329
#   Contrastive weight: 0.0150
#   -> Synced checkpoints to Drive (epoch 39)
# Epoch 40: 100% 55/55 [01:12<00:00,  1.32s/it, loss=0.6035, text=Y]
# Epoch 40: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.12it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 40: train_loss=0.9351
#   With text:    val_loss=0.5130, val_dice=0.8214
#   Without text: val_loss=0.5129, val_dice=0.8216
#   Contrastive weight: 0.0167
# Epoch 41: 100% 55/55 [01:12<00:00,  1.32s/it, loss=0.5861, text=Y]
# Epoch 41: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 41: train_loss=0.9062
#   With text:    val_loss=0.5236, val_dice=0.8188
#   Without text: val_loss=0.5236, val_dice=0.8189
#   Contrastive weight: 0.0183
# Epoch 42: 100% 55/55 [01:07<00:00,  1.22s/it, loss=0.7657, text=Y]
# Epoch 42: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:10<00:00,  1.29it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 42: train_loss=0.8822
#   With text:    val_loss=0.4807, val_dice=0.8393
#   Without text: val_loss=0.4804, val_dice=0.8396
#   Contrastive weight: 0.0200
#   -> New best (no-text): 0.8396
#   -> New best (with-text): 0.8393
# Epoch 43: 100% 55/55 [01:07<00:00,  1.22s/it, loss=0.6823, text=N]
# Epoch 43: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.30it/s]
# Epoch 43: train_loss=0.9117
#   With text:    val_loss=0.4880, val_dice=0.8416
#   Without text: val_loss=0.4881, val_dice=0.8417
#   Contrastive weight: 0.0217
#   -> New best (no-text): 0.8417
#   -> New best (with-text): 0.8416
# Epoch 44: 100% 55/55 [01:08<00:00,  1.24s/it, loss=0.9742, text=Y]
# Epoch 44: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.17it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 44: train_loss=0.8622
#   With text:    val_loss=0.4734, val_dice=0.8407
#   Without text: val_loss=0.4735, val_dice=0.8407
#   Contrastive weight: 0.0233
# Epoch 45: 100% 55/55 [01:05<00:00,  1.19s/it, loss=0.9012, text=Y]
# Epoch 45: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 45: train_loss=0.8799
#   With text:    val_loss=0.5018, val_dice=0.8363
#   Without text: val_loss=0.5032, val_dice=0.8358
#   Contrastive weight: 0.0250
# Epoch 46: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.6166, text=N]
# Epoch 46: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 46: train_loss=0.9739
#   With text:    val_loss=0.4850, val_dice=0.8382
#   Without text: val_loss=0.4846, val_dice=0.8385
#   Contrastive weight: 0.0267
# Epoch 47: 100% 55/55 [01:14<00:00,  1.36s/it, loss=0.7966, text=Y]
# Epoch 47: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 47: train_loss=0.8637
#   With text:    val_loss=0.4480, val_dice=0.8539
#   Without text: val_loss=0.4482, val_dice=0.8539
#   Contrastive weight: 0.0283
#   -> New best (no-text): 0.8539
#   -> New best (with-text): 0.8539
# Epoch 48: 100% 55/55 [01:12<00:00,  1.32s/it, loss=1.4062, text=Y]
# Epoch 48: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.16it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 48: train_loss=0.8802
#   With text:    val_loss=0.4943, val_dice=0.8428
#   Without text: val_loss=0.4945, val_dice=0.8429
#   Contrastive weight: 0.0300
# Epoch 49: 100% 55/55 [01:12<00:00,  1.33s/it, loss=1.2805, text=Y]
# Epoch 49: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 49: train_loss=0.8742
#   With text:    val_loss=0.4714, val_dice=0.8423
#   Without text: val_loss=0.4714, val_dice=0.8425
#   Contrastive weight: 0.0317
#   -> Synced checkpoints to Drive (epoch 49)
# Epoch 50: 100% 55/55 [01:13<00:00,  1.33s/it, loss=0.9489, text=Y]
# Epoch 50: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.14it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.25it/s]
# Epoch 50: train_loss=0.9002
#   With text:    val_loss=0.4652, val_dice=0.8491
#   Without text: val_loss=0.4658, val_dice=0.8489
#   Contrastive weight: 0.0333
# Epoch 51: 100% 55/55 [01:12<00:00,  1.31s/it, loss=1.0612, text=Y]
# Epoch 51: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 51: train_loss=0.8717
#   With text:    val_loss=0.4469, val_dice=0.8489
#   Without text: val_loss=0.4468, val_dice=0.8486
#   Contrastive weight: 0.0350
# Epoch 52: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.8813, text=Y]
# Epoch 52: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:10<00:00,  1.28it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.30it/s]
# Epoch 52: train_loss=0.8907
#   With text:    val_loss=0.4605, val_dice=0.8398
#   Without text: val_loss=0.4605, val_dice=0.8395
#   Contrastive weight: 0.0367
# Epoch 53: 100% 55/55 [01:08<00:00,  1.25s/it, loss=0.6423, text=Y]
# Epoch 53: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:10<00:00,  1.28it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 53: train_loss=0.8962
#   With text:    val_loss=0.4628, val_dice=0.8487
#   Without text: val_loss=0.4612, val_dice=0.8490
#   Contrastive weight: 0.0383
# Epoch 54: 100% 55/55 [01:08<00:00,  1.25s/it, loss=0.7513, text=Y]
# Epoch 54: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 54: train_loss=0.8639
#   With text:    val_loss=0.4484, val_dice=0.8497
#   Without text: val_loss=0.4485, val_dice=0.8495
#   Contrastive weight: 0.0400
# Epoch 55: 100% 55/55 [01:08<00:00,  1.25s/it, loss=1.0698, text=Y]
# Epoch 55: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 55: train_loss=0.8525
#   With text:    val_loss=0.4650, val_dice=0.8460
#   Without text: val_loss=0.4659, val_dice=0.8455
#   Contrastive weight: 0.0417
# Epoch 56: 100% 55/55 [01:08<00:00,  1.25s/it, loss=0.9851, text=Y]
# Epoch 56: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 56: train_loss=0.8539
#   With text:    val_loss=0.4495, val_dice=0.8504
#   Without text: val_loss=0.4499, val_dice=0.8501
#   Contrastive weight: 0.0433
# Epoch 57: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.5774, text=Y]
# Epoch 57: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 57: train_loss=0.8618
#   With text:    val_loss=0.4993, val_dice=0.8531
#   Without text: val_loss=0.4985, val_dice=0.8526
#   Contrastive weight: 0.0450
# Epoch 58: 100% 55/55 [01:13<00:00,  1.33s/it, loss=0.8398, text=Y]
# Epoch 58: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 58: train_loss=0.8803
#   With text:    val_loss=0.4270, val_dice=0.8611
#   Without text: val_loss=0.4269, val_dice=0.8608
#   Contrastive weight: 0.0467
#   -> New best (no-text): 0.8608
#   -> New best (with-text): 0.8611
# Epoch 59: 100% 55/55 [01:11<00:00,  1.31s/it, loss=0.6643, text=Y]
# Epoch 59: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.22it/s]
# Epoch 59: train_loss=0.8342
#   With text:    val_loss=0.4386, val_dice=0.8504
#   Without text: val_loss=0.4381, val_dice=0.8508
#   Contrastive weight: 0.0483
#   -> Synced checkpoints to Drive (epoch 59)
# Epoch 60: 100% 55/55 [01:17<00:00,  1.41s/it, loss=0.7572, text=Y]
# Epoch 60: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 60: train_loss=0.8365
#   With text:    val_loss=0.4457, val_dice=0.8582
#   Without text: val_loss=0.4458, val_dice=0.8582
#   Contrastive weight: 0.0500
# Epoch 61: 100% 55/55 [01:10<00:00,  1.28s/it, loss=0.7053, text=Y]
# Epoch 61: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 61: train_loss=0.8737
#   With text:    val_loss=0.4284, val_dice=0.8625
#   Without text: val_loss=0.4283, val_dice=0.8624
#   Contrastive weight: 0.0500
#   -> New best (no-text): 0.8624
#   -> New best (with-text): 0.8625
# Epoch 62: 100% 55/55 [01:11<00:00,  1.29s/it, loss=0.7916, text=Y]
# Epoch 62: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 62: train_loss=0.8467
#   With text:    val_loss=0.4526, val_dice=0.8415
#   Without text: val_loss=0.4529, val_dice=0.8414
#   Contrastive weight: 0.0500
# Epoch 63: 100% 55/55 [01:07<00:00,  1.23s/it, loss=1.1536, text=Y]
# Epoch 63: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 63: train_loss=0.8507
#   With text:    val_loss=0.4549, val_dice=0.8673
#   Without text: val_loss=0.4541, val_dice=0.8675
#   Contrastive weight: 0.0500
#   -> New best (no-text): 0.8675
#   -> New best (with-text): 0.8673
# Epoch 64: 100% 55/55 [01:12<00:00,  1.31s/it, loss=0.6075, text=Y]
# Epoch 64: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 64: train_loss=0.8298
#   With text:    val_loss=0.4325, val_dice=0.8642
#   Without text: val_loss=0.4319, val_dice=0.8644
#   Contrastive weight: 0.0500
# Epoch 65: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.7273, text=Y]
# Epoch 65: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 65: train_loss=0.8437
#   With text:    val_loss=0.4417, val_dice=0.8504
#   Without text: val_loss=0.4422, val_dice=0.8502
#   Contrastive weight: 0.0500
# Epoch 66: 100% 55/55 [01:13<00:00,  1.34s/it, loss=0.7151, text=Y]
# Epoch 66: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 66: train_loss=0.8172
#   With text:    val_loss=0.4415, val_dice=0.8465
#   Without text: val_loss=0.4415, val_dice=0.8465
#   Contrastive weight: 0.0500
# Epoch 67: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.8988, text=Y]
# Epoch 67: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 67: train_loss=0.8175
#   With text:    val_loss=0.4497, val_dice=0.8508
#   Without text: val_loss=0.4505, val_dice=0.8504
#   Contrastive weight: 0.0500
# Epoch 68: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.6358, text=N]
# Epoch 68: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 68: train_loss=0.8174
#   With text:    val_loss=0.4003, val_dice=0.8673
#   Without text: val_loss=0.4006, val_dice=0.8669
#   Contrastive weight: 0.0500
# Epoch 69: 100% 55/55 [01:08<00:00,  1.25s/it, loss=0.7173, text=Y]
# Epoch 69: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 69: train_loss=0.7681
#   With text:    val_loss=0.4103, val_dice=0.8663
#   Without text: val_loss=0.4112, val_dice=0.8657
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 69)
# Epoch 70: 100% 55/55 [01:13<00:00,  1.33s/it, loss=0.9173, text=Y]
# Epoch 70: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.15it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 70: train_loss=0.8288
#   With text:    val_loss=0.4129, val_dice=0.8580
#   Without text: val_loss=0.4132, val_dice=0.8577
#   Contrastive weight: 0.0500
# Epoch 71: 100% 55/55 [01:07<00:00,  1.23s/it, loss=0.7607, text=Y]
# Epoch 71: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 71: train_loss=0.7975
#   With text:    val_loss=0.4071, val_dice=0.8698
#   Without text: val_loss=0.4058, val_dice=0.8696
#   Contrastive weight: 0.0500
#   -> New best (no-text): 0.8696
#   -> New best (with-text): 0.8698
# Epoch 72: 100% 55/55 [01:13<00:00,  1.34s/it, loss=0.9243, text=Y]
# Epoch 72: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 72: train_loss=0.8337
#   With text:    val_loss=0.4213, val_dice=0.8602
#   Without text: val_loss=0.4225, val_dice=0.8594
#   Contrastive weight: 0.0500
# Epoch 73: 100% 55/55 [01:11<00:00,  1.29s/it, loss=0.4115, text=Y]
# Epoch 73: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 73: train_loss=0.7717
#   With text:    val_loss=0.4074, val_dice=0.8698
#   Without text: val_loss=0.4076, val_dice=0.8684
#   Contrastive weight: 0.0500
#   -> New best (with-text): 0.8698
# Epoch 74: 100% 55/55 [01:06<00:00,  1.20s/it, loss=0.6120, text=Y]
# Epoch 74: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 74: train_loss=0.7438
#   With text:    val_loss=0.4428, val_dice=0.8583
#   Without text: val_loss=0.4408, val_dice=0.8582
#   Contrastive weight: 0.0500
# Epoch 75: 100% 55/55 [01:13<00:00,  1.33s/it, loss=1.2630, text=Y]
# Epoch 75: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 75: train_loss=0.7597
#   With text:    val_loss=0.4180, val_dice=0.8729
#   Without text: val_loss=0.4096, val_dice=0.8729
#   Contrastive weight: 0.0500
#   -> New best (no-text): 0.8729
#   -> New best (with-text): 0.8729
# Epoch 76: 100% 55/55 [01:12<00:00,  1.33s/it, loss=0.7303, text=N]
# Epoch 76: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.17it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.25it/s]
# Epoch 76: train_loss=0.7931
#   With text:    val_loss=0.4066, val_dice=0.8708
#   Without text: val_loss=0.4033, val_dice=0.8705
#   Contrastive weight: 0.0500
# Epoch 77: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.6258, text=N]
# Epoch 77: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 77: train_loss=0.7449
#   With text:    val_loss=0.4087, val_dice=0.8657
#   Without text: val_loss=0.4098, val_dice=0.8646
#   Contrastive weight: 0.0500
# Epoch 78: 100% 55/55 [01:10<00:00,  1.28s/it, loss=0.6908, text=Y]
# Epoch 78: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 78: train_loss=0.7367
#   With text:    val_loss=0.4082, val_dice=0.8698
#   Without text: val_loss=0.4096, val_dice=0.8701
#   Contrastive weight: 0.0500
# Epoch 79: 100% 55/55 [01:10<00:00,  1.28s/it, loss=0.5021, text=Y]
# Epoch 79: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 79: train_loss=0.7164
#   With text:    val_loss=0.4248, val_dice=0.8722
#   Without text: val_loss=0.4203, val_dice=0.8721
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 79)
# Epoch 80: 100% 55/55 [01:09<00:00,  1.27s/it, loss=1.6150, text=Y]
# Epoch 80: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.16it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.25it/s]
# Epoch 80: train_loss=0.7432
#   With text:    val_loss=0.4002, val_dice=0.8758
#   Without text: val_loss=0.3984, val_dice=0.8756
#   Contrastive weight: 0.0500
#   -> New best (no-text): 0.8756
#   -> New best (with-text): 0.8758
# Epoch 81: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.5342, text=Y]
# Epoch 81: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.15it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 81: train_loss=0.8121
#   With text:    val_loss=0.4095, val_dice=0.8596
#   Without text: val_loss=0.4075, val_dice=0.8585
#   Contrastive weight: 0.0500
# Epoch 82: 100% 55/55 [01:08<00:00,  1.25s/it, loss=0.8265, text=Y]
# Epoch 82: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.16it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 82: train_loss=0.7127
#   With text:    val_loss=0.3918, val_dice=0.8737
#   Without text: val_loss=0.3897, val_dice=0.8734
#   Contrastive weight: 0.0500
# Epoch 83: 100% 55/55 [01:10<00:00,  1.28s/it, loss=0.6544, text=Y]
# Epoch 83: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 83: train_loss=0.7334
#   With text:    val_loss=0.4396, val_dice=0.8650
#   Without text: val_loss=0.4312, val_dice=0.8650
#   Contrastive weight: 0.0500
# Epoch 84: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.6925, text=Y]
# Epoch 84: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 84: train_loss=0.7186
#   With text:    val_loss=0.4019, val_dice=0.8726
#   Without text: val_loss=0.3987, val_dice=0.8726
#   Contrastive weight: 0.0500
# Epoch 85: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.5814, text=Y]
# Epoch 85: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 85: train_loss=0.7534
#   With text:    val_loss=0.3926, val_dice=0.8716
#   Without text: val_loss=0.3917, val_dice=0.8711
#   Contrastive weight: 0.0500
# Epoch 86: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.6225, text=N]
# Epoch 86: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.25it/s]
# Epoch 86: train_loss=0.7013
#   With text:    val_loss=0.4104, val_dice=0.8747
#   Without text: val_loss=0.3961, val_dice=0.8749
#   Contrastive weight: 0.0500
# Epoch 87: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.6769, text=Y]
# Epoch 87: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 87: train_loss=0.7339
#   With text:    val_loss=0.4039, val_dice=0.8735
#   Without text: val_loss=0.3978, val_dice=0.8731
#   Contrastive weight: 0.0500
# Epoch 88: 100% 55/55 [01:14<00:00,  1.35s/it, loss=0.4942, text=Y]
# Epoch 88: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 88: train_loss=0.7302
#   With text:    val_loss=0.4424, val_dice=0.8701
#   Without text: val_loss=0.4248, val_dice=0.8700
#   Contrastive weight: 0.0500
# Epoch 89: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.5555, text=Y]
# Epoch 89: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 89: train_loss=0.7183
#   With text:    val_loss=0.4056, val_dice=0.8715
#   Without text: val_loss=0.4041, val_dice=0.8707
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 89)
# Epoch 90: 100% 55/55 [01:12<00:00,  1.32s/it, loss=0.7392, text=N]
# Epoch 90: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 90: train_loss=0.7166
#   With text:    val_loss=0.4068, val_dice=0.8785
#   Without text: val_loss=0.3972, val_dice=0.8786
#   Contrastive weight: 0.0500
#   -> New best (no-text): 0.8786
#   -> New best (with-text): 0.8785
# Epoch 91: 100% 55/55 [01:08<00:00,  1.25s/it, loss=0.6260, text=Y]
# Epoch 91: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.10it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 91: train_loss=0.6910
#   With text:    val_loss=0.4094, val_dice=0.8642
#   Without text: val_loss=0.4082, val_dice=0.8628
#   Contrastive weight: 0.0500
# Epoch 92: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.5986, text=Y]
# Epoch 92: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.21it/s]
# Epoch 92: train_loss=0.7249
#   With text:    val_loss=0.4058, val_dice=0.8710
#   Without text: val_loss=0.4027, val_dice=0.8706
#   Contrastive weight: 0.0500
# Epoch 93: 100% 55/55 [01:12<00:00,  1.31s/it, loss=0.6450, text=N]
# Epoch 93: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 93: train_loss=0.7007
#   With text:    val_loss=0.3910, val_dice=0.8700
#   Without text: val_loss=0.3901, val_dice=0.8694
#   Contrastive weight: 0.0500
# Epoch 94: 100% 55/55 [01:08<00:00,  1.24s/it, loss=0.5717, text=Y]
# Epoch 94: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 94: train_loss=0.7159
#   With text:    val_loss=0.4264, val_dice=0.8746
#   Without text: val_loss=0.4167, val_dice=0.8750
#   Contrastive weight: 0.0500
# Epoch 95: 100% 55/55 [01:05<00:00,  1.20s/it, loss=0.8984, text=Y]
# Epoch 95: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:10<00:00,  1.28it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 95: train_loss=0.7030
#   With text:    val_loss=0.4024, val_dice=0.8718
#   Without text: val_loss=0.4022, val_dice=0.8716
#   Contrastive weight: 0.0500
# Epoch 96: 100% 55/55 [01:14<00:00,  1.35s/it, loss=0.5385, text=Y]
# Epoch 96: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 96: train_loss=0.7189
#   With text:    val_loss=0.4054, val_dice=0.8700
#   Without text: val_loss=0.4056, val_dice=0.8692
#   Contrastive weight: 0.0500
# Epoch 97: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.5185, text=Y]
# Epoch 97: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.27it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 97: train_loss=0.7013
#   With text:    val_loss=0.4218, val_dice=0.8605
#   Without text: val_loss=0.4216, val_dice=0.8606
#   Contrastive weight: 0.0500
# Epoch 98: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.6424, text=Y]
# Epoch 98: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 98: train_loss=0.7455
#   With text:    val_loss=0.4067, val_dice=0.8739
#   Without text: val_loss=0.4031, val_dice=0.8732
#   Contrastive weight: 0.0500
# Epoch 99: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.5689, text=Y]
# Epoch 99: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 99: train_loss=0.7037
#   With text:    val_loss=0.3970, val_dice=0.8691
#   Without text: val_loss=0.3966, val_dice=0.8684
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 99)
# Epoch 100: 100% 55/55 [01:12<00:00,  1.32s/it, loss=0.6339, text=Y]
# Epoch 100: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 100: train_loss=0.6857
#   With text:    val_loss=0.4024, val_dice=0.8763
#   Without text: val_loss=0.3929, val_dice=0.8767
#   Contrastive weight: 0.0500
# Epoch 101: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.4864, text=Y]
# Epoch 101: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 101: train_loss=0.6906
#   With text:    val_loss=0.3914, val_dice=0.8687
#   Without text: val_loss=0.3915, val_dice=0.8681
#   Contrastive weight: 0.0500
# Epoch 102: 100% 55/55 [01:12<00:00,  1.32s/it, loss=0.6510, text=N]
# Epoch 102: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 102: train_loss=0.6880
#   With text:    val_loss=0.3987, val_dice=0.8679
#   Without text: val_loss=0.3968, val_dice=0.8678
#   Contrastive weight: 0.0500
# Epoch 103: 100% 55/55 [01:07<00:00,  1.24s/it, loss=0.6614, text=Y]
# Epoch 103: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 103: train_loss=0.6870
#   With text:    val_loss=0.4081, val_dice=0.8651
#   Without text: val_loss=0.4059, val_dice=0.8651
#   Contrastive weight: 0.0500
# Epoch 104: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.7152, text=Y]
# Epoch 104: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 104: train_loss=0.7417
#   With text:    val_loss=0.4010, val_dice=0.8772
#   Without text: val_loss=0.3997, val_dice=0.8772
#   Contrastive weight: 0.0500
# Epoch 105: 100% 55/55 [01:10<00:00,  1.28s/it, loss=0.6375, text=Y]
# Epoch 105: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 105: train_loss=0.6989
#   With text:    val_loss=0.3906, val_dice=0.8776
#   Without text: val_loss=0.3903, val_dice=0.8777
#   Contrastive weight: 0.0500
# Epoch 106: 100% 55/55 [01:12<00:00,  1.33s/it, loss=0.5618, text=Y]
# Epoch 106: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 106: train_loss=0.6713
#   With text:    val_loss=0.4215, val_dice=0.8718
#   Without text: val_loss=0.4206, val_dice=0.8725
#   Contrastive weight: 0.0500
# Epoch 107: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.4521, text=N]
# Epoch 107: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 107: train_loss=0.6904
#   With text:    val_loss=0.3885, val_dice=0.8750
#   Without text: val_loss=0.3882, val_dice=0.8753
#   Contrastive weight: 0.0500
# Epoch 108: 100% 55/55 [01:13<00:00,  1.33s/it, loss=0.5919, text=Y]
# Epoch 108: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 108: train_loss=0.6921
#   With text:    val_loss=0.3990, val_dice=0.8698
#   Without text: val_loss=0.3986, val_dice=0.8702
#   Contrastive weight: 0.0500
# Epoch 109: 100% 55/55 [01:08<00:00,  1.25s/it, loss=1.2178, text=Y]
# Epoch 109: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 109: train_loss=0.7049
#   With text:    val_loss=0.3923, val_dice=0.8767
#   Without text: val_loss=0.3902, val_dice=0.8768
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 109)
# Epoch 110: 100% 55/55 [01:12<00:00,  1.32s/it, loss=0.6638, text=N]
# Epoch 110: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.16it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 110: train_loss=0.7150
#   With text:    val_loss=0.3958, val_dice=0.8769
#   Without text: val_loss=0.3930, val_dice=0.8769
#   Contrastive weight: 0.0500
# Epoch 111: 100% 55/55 [01:08<00:00,  1.24s/it, loss=0.4817, text=Y]
# Epoch 111: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 111: train_loss=0.6698
#   With text:    val_loss=0.3912, val_dice=0.8777
#   Without text: val_loss=0.3874, val_dice=0.8778
#   Contrastive weight: 0.0500
# Epoch 112: 100% 55/55 [01:10<00:00,  1.28s/it, loss=1.0149, text=Y]
# Epoch 112: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 112: train_loss=0.7317
#   With text:    val_loss=0.3953, val_dice=0.8727
#   Without text: val_loss=0.3942, val_dice=0.8723
#   Contrastive weight: 0.0500
# Epoch 113: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.6213, text=Y]
# Epoch 113: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 113: train_loss=0.6760
#   With text:    val_loss=0.4006, val_dice=0.8744
#   Without text: val_loss=0.3970, val_dice=0.8744
#   Contrastive weight: 0.0500
# ...
# Epoch 135: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 135: train_loss=0.6657
#   With text:    val_loss=0.4187, val_dice=0.8788
#   Without text: val_loss=0.4129, val_dice=0.8795
#   Contrastive weight: 0.0500
# Epoch 136: 100% 55/55 [01:10<00:00,  1.28s/it, loss=0.5493, text=Y]
# Epoch 136: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.27it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 136: train_loss=0.6512
#   With text:    val_loss=0.4014, val_dice=0.8799
#   Without text: val_loss=0.3917, val_dice=0.8809
#   Contrastive weight: 0.0500
#   -> New best (no-text): 0.8809
# Epoch 137: 100% 55/55 [01:11<00:00,  1.31s/it, loss=0.9190, text=Y]
# Epoch 137: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 137: train_loss=0.6642
#   With text:    val_loss=0.3995, val_dice=0.8787
#   Without text: val_loss=0.3825, val_dice=0.8795
#   Contrastive weight: 0.0500
# Epoch 138: 100% 55/55 [01:08<00:00,  1.25s/it, loss=0.4266, text=N]
# Epoch 138: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 138: train_loss=0.6524
#   With text:    val_loss=0.4045, val_dice=0.8763
#   Without text: val_loss=0.3893, val_dice=0.8772
#   Contrastive weight: 0.0500
# Epoch 139: 100% 55/55 [01:14<00:00,  1.36s/it, loss=0.6711, text=Y]
# Epoch 139: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 139: train_loss=0.6556
#   With text:    val_loss=0.4008, val_dice=0.8678
#   Without text: val_loss=0.3901, val_dice=0.8704
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 139)
# Epoch 140: 100% 55/55 [01:06<00:00,  1.21s/it, loss=0.5428, text=N]
# Epoch 140: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.15it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 140: train_loss=0.6852
#   With text:    val_loss=0.4184, val_dice=0.8781
#   Without text: val_loss=0.4118, val_dice=0.8792
#   Contrastive weight: 0.0500
# Epoch 141: 100% 55/55 [01:13<00:00,  1.33s/it, loss=1.1065, text=Y]
# Epoch 141: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 141: train_loss=0.6533
#   With text:    val_loss=0.4029, val_dice=0.8732
#   Without text: val_loss=0.3892, val_dice=0.8752
#   Contrastive weight: 0.0500
# Epoch 142: 100% 55/55 [01:08<00:00,  1.24s/it, loss=0.5157, text=Y]
# Epoch 142: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 142: train_loss=0.6649
#   With text:    val_loss=0.4088, val_dice=0.8772
#   Without text: val_loss=0.3993, val_dice=0.8775
#   Contrastive weight: 0.0500
# Epoch 143: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.5612, text=Y]
# Epoch 143: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 143: train_loss=0.6369
#   With text:    val_loss=0.4125, val_dice=0.8782
#   Without text: val_loss=0.3995, val_dice=0.8792
#   Contrastive weight: 0.0500
# Epoch 144: 100% 55/55 [01:11<00:00,  1.31s/it, loss=0.4988, text=Y]
# Epoch 144: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 144: train_loss=0.6571
#   With text:    val_loss=0.4101, val_dice=0.8780
#   Without text: val_loss=0.3965, val_dice=0.8779
#   Contrastive weight: 0.0500
# Epoch 145: 100% 55/55 [01:15<00:00,  1.38s/it, loss=0.5761, text=Y]
# Epoch 145: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 145: train_loss=0.6772
#   With text:    val_loss=0.4087, val_dice=0.8779
#   Without text: val_loss=0.3909, val_dice=0.8788
#   Contrastive weight: 0.0500
# Epoch 146: 100% 55/55 [01:13<00:00,  1.34s/it, loss=0.6128, text=Y]
# Epoch 146: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:10<00:00,  1.28it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 146: train_loss=0.6718
#   With text:    val_loss=0.4075, val_dice=0.8782
#   Without text: val_loss=0.3908, val_dice=0.8784
#   Contrastive weight: 0.0500
# Epoch 147: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.6885, text=Y]
# Epoch 147: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.27it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 147: train_loss=0.6347
#   With text:    val_loss=0.4003, val_dice=0.8767
#   Without text: val_loss=0.3831, val_dice=0.8781
#   Contrastive weight: 0.0500
# Epoch 148: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.7813, text=N]
# Epoch 148: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 148: train_loss=0.6324
#   With text:    val_loss=0.4127, val_dice=0.8802
#   Without text: val_loss=0.3999, val_dice=0.8797
#   Contrastive weight: 0.0500
#   -> New best (with-text): 0.8802
# Epoch 149: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.4866, text=Y]
# Epoch 149: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 149: train_loss=0.6416
#   With text:    val_loss=0.4085, val_dice=0.8772
#   Without text: val_loss=0.3890, val_dice=0.8778
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 149)
# Epoch 150: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.4694, text=Y]
# Epoch 150: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 150: train_loss=0.6937
#   With text:    val_loss=0.4148, val_dice=0.8793
#   Without text: val_loss=0.4060, val_dice=0.8789
#   Contrastive weight: 0.0500
# Epoch 151: 100% 55/55 [01:13<00:00,  1.33s/it, loss=0.5668, text=Y]
# Epoch 151: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 151: train_loss=0.6277
#   With text:    val_loss=0.3988, val_dice=0.8778
#   Without text: val_loss=0.3867, val_dice=0.8781
#   Contrastive weight: 0.0500
# Epoch 152: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.4684, text=Y]
# Epoch 152: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 152: train_loss=0.6315
#   With text:    val_loss=0.3953, val_dice=0.8793
#   Without text: val_loss=0.3841, val_dice=0.8797
#   Contrastive weight: 0.0500
# Epoch 153: 100% 55/55 [01:14<00:00,  1.35s/it, loss=0.4549, text=N]
# Epoch 153: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:10<00:00,  1.27it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 153: train_loss=0.6364
#   With text:    val_loss=0.3953, val_dice=0.8798
#   Without text: val_loss=0.3857, val_dice=0.8795
#   Contrastive weight: 0.0500
# Epoch 154: 100% 55/55 [01:08<00:00,  1.24s/it, loss=0.6174, text=Y]
# Epoch 154: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 154: train_loss=0.6313
#   With text:    val_loss=0.3967, val_dice=0.8755
#   Without text: val_loss=0.3873, val_dice=0.8754
#   Contrastive weight: 0.0500
# Epoch 155: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.8300, text=Y]
# Epoch 155: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:10<00:00,  1.27it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.30it/s]
# Epoch 155: train_loss=0.6523
#   With text:    val_loss=0.4011, val_dice=0.8797
#   Without text: val_loss=0.3898, val_dice=0.8793
#   Contrastive weight: 0.0500
# Epoch 156: 100% 55/55 [01:10<00:00,  1.28s/it, loss=0.8670, text=Y]
# Epoch 156: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 156: train_loss=0.6359
#   With text:    val_loss=0.4041, val_dice=0.8784
#   Without text: val_loss=0.3922, val_dice=0.8780
#   Contrastive weight: 0.0500
# Epoch 157: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.8872, text=Y]
# Epoch 157: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 157: train_loss=0.6317
#   With text:    val_loss=0.4078, val_dice=0.8800
#   Without text: val_loss=0.3959, val_dice=0.8790
#   Contrastive weight: 0.0500
# Epoch 158: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.5621, text=Y]
# Epoch 158: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 158: train_loss=0.6570
#   With text:    val_loss=0.4145, val_dice=0.8782
#   Without text: val_loss=0.4088, val_dice=0.8776
#   Contrastive weight: 0.0500
# Epoch 159: 100% 55/55 [01:13<00:00,  1.34s/it, loss=0.4846, text=Y]
# Epoch 159: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.27it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 159: train_loss=0.6069
#   With text:    val_loss=0.4071, val_dice=0.8747
#   Without text: val_loss=0.3940, val_dice=0.8763
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 159)
# Epoch 160: 100% 55/55 [01:08<00:00,  1.24s/it, loss=0.8398, text=Y]
# Epoch 160: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 160: train_loss=0.6589
#   With text:    val_loss=0.4016, val_dice=0.8784
#   Without text: val_loss=0.3938, val_dice=0.8786
#   Contrastive weight: 0.0500
# Epoch 161: 100% 55/55 [01:13<00:00,  1.33s/it, loss=0.5780, text=Y]
# Epoch 161: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 161: train_loss=0.6778
#   With text:    val_loss=0.3963, val_dice=0.8787
#   Without text: val_loss=0.3885, val_dice=0.8788
#   Contrastive weight: 0.0500
# Epoch 162: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.8740, text=Y]
# Epoch 162: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 162: train_loss=0.6374
#   With text:    val_loss=0.3998, val_dice=0.8795
#   Without text: val_loss=0.3925, val_dice=0.8790
#   Contrastive weight: 0.0500
# Epoch 163: 100% 55/55 [01:03<00:00,  1.16s/it, loss=0.5662, text=Y]
# Epoch 163: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 163: train_loss=0.6175
#   With text:    val_loss=0.3919, val_dice=0.8805
#   Without text: val_loss=0.3833, val_dice=0.8797
#   Contrastive weight: 0.0500
#   -> New best (with-text): 0.8805
# Epoch 164: 100% 55/55 [01:08<00:00,  1.25s/it, loss=0.7101, text=Y]
# Epoch 164: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 164: train_loss=0.6573
#   With text:    val_loss=0.3975, val_dice=0.8778
#   Without text: val_loss=0.3871, val_dice=0.8776
#   Contrastive weight: 0.0500
# Epoch 165: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.6208, text=N]
# Epoch 165: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.30it/s]
# Epoch 165: train_loss=0.6142
#   With text:    val_loss=0.3921, val_dice=0.8808
#   Without text: val_loss=0.3809, val_dice=0.8804
#   Contrastive weight: 0.0500
#   -> New best (with-text): 0.8808
# Epoch 166: 100% 55/55 [01:15<00:00,  1.37s/it, loss=0.4428, text=N]
# Epoch 166: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.22it/s]
# Epoch 166: train_loss=0.6064
#   With text:    val_loss=0.3960, val_dice=0.8796
#   Without text: val_loss=0.3832, val_dice=0.8798
#   Contrastive weight: 0.0500
# Epoch 167: 100% 55/55 [01:10<00:00,  1.27s/it, loss=0.7767, text=Y]
# Epoch 167: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 167: train_loss=0.6846
#   With text:    val_loss=0.3979, val_dice=0.8806
#   Without text: val_loss=0.3860, val_dice=0.8801
#   Contrastive weight: 0.0500
# Epoch 168: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.6014, text=Y]
# Epoch 168: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 168: train_loss=0.6366
#   With text:    val_loss=0.3989, val_dice=0.8803
#   Without text: val_loss=0.3867, val_dice=0.8800
#   Contrastive weight: 0.0500
# Epoch 169: 100% 55/55 [01:14<00:00,  1.35s/it, loss=0.9922, text=Y]
# Epoch 169: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 169: train_loss=0.6442
#   With text:    val_loss=0.4043, val_dice=0.8805
#   Without text: val_loss=0.3963, val_dice=0.8795
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 169)
# Epoch 170: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.6365, text=Y]
# Epoch 170: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.24it/s]
# Epoch 170: train_loss=0.6257
#   With text:    val_loss=0.4027, val_dice=0.8802
#   Without text: val_loss=0.3921, val_dice=0.8799
#   Contrastive weight: 0.0500
# Epoch 171: 100% 55/55 [01:07<00:00,  1.23s/it, loss=0.6358, text=Y]
# Epoch 171: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 171: train_loss=0.6350
#   With text:    val_loss=0.4020, val_dice=0.8800
#   Without text: val_loss=0.3922, val_dice=0.8787
#   Contrastive weight: 0.0500
# Epoch 172: 100% 55/55 [01:12<00:00,  1.31s/it, loss=0.5044, text=N]
# Epoch 172: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.22it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 172: train_loss=0.6337
#   With text:    val_loss=0.3981, val_dice=0.8794
#   Without text: val_loss=0.3864, val_dice=0.8793
#   Contrastive weight: 0.0500
# Epoch 173: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.5731, text=Y]
# Epoch 173: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:10<00:00,  1.27it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 173: train_loss=0.6488
#   With text:    val_loss=0.4013, val_dice=0.8794
#   Without text: val_loss=0.3909, val_dice=0.8785
#   Contrastive weight: 0.0500
# Epoch 174: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.6001, text=Y]
# Epoch 174: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 174: train_loss=0.6347
#   With text:    val_loss=0.4009, val_dice=0.8809
#   Without text: val_loss=0.3913, val_dice=0.8797
#   Contrastive weight: 0.0500
#   -> New best (with-text): 0.8809
# Epoch 175: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.6924, text=Y]
# Epoch 175: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 175: train_loss=0.6513
#   With text:    val_loss=0.3993, val_dice=0.8806
#   Without text: val_loss=0.3899, val_dice=0.8797
#   Contrastive weight: 0.0500
# Epoch 176: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.5879, text=Y]
# Epoch 176: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.30it/s]
# Epoch 176: train_loss=0.6193
#   With text:    val_loss=0.3989, val_dice=0.8786
#   Without text: val_loss=0.3890, val_dice=0.8784
#   Contrastive weight: 0.0500
#
# Early stopping triggered at epoch 176
#
# Training complete!
# Best Dice (with text): 0.8809
# Best Dice (no text):   0.8809
# Synced checkpoints to /content/drive/MyDrive/TextMamba3D/checkpoints
# Best checkpoint saved: /content/drive/MyDrive/TextMamba3D/checkpoints/best_v4.2.pth

# %% [markdown]
# ## 5. Full-Volume Evaluation (Sliding Window)
#
# Evaluate best checkpoint in both modes (with-text and no-text) using sliding window inference with Gaussian importance weighting.

# %%
os.chdir(REPO_DIR)

# Find best checkpoint
ckpt = os.path.join(REPO_DIR, "checkpoints/best.pth")
if not os.path.exists(ckpt):
    ckpt = os.path.join(DRIVE_CKPT, "best_v4.2.pth")

if os.path.exists(ckpt):
    # Evaluate WITH text guidance
    print("=" * 60)
    print("Evaluation: With Text (MultiScale fusion + FG-Contrastive)")
    print("=" * 60)
    # !python evaluate_full.py \
        --config configs/textbrats_a100.yaml \
        --checkpoint "{ckpt}" \
        --split test \
        --use-text \
        --overlap 0.5

    print()

    # Evaluate WITHOUT text (fusion bypassed, pure vision)
    print("=" * 60)
    print("Evaluation: Without Text (fusion bypassed)")
    print("=" * 60)
    # !python evaluate_full.py \
        --config configs/textbrats_a100.yaml \
        --checkpoint "{ckpt}" \
        --split test \
        --no-text \
        --overlap 0.5
else:
    print(f"Checkpoint not found. Train first.")
# Out:
# ============================================================
# Evaluation: With Text (MultiScale fusion + FG-Contrastive)
# ============================================================
# Loading weights: 100% 199/199 [00:00<00:00, 1546.33it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#
# Evaluating:  92% 87/95 [13:19<01:11,  8.99s/it]  BraTS20_Training_369: Dice=0.9307 (ET=0.9080, TC=0.9398, WT=0.9441) HD95_ET=1.00
# Evaluating:  93% 88/95 [13:29<01:05,  9.32s/it]  BraTS20_Training_021: Dice=0.7821 (ET=0.6731, TC=0.8775, WT=0.7957) HD95_ET=1.73
# Evaluating:  94% 89/95 [13:37<00:54,  9.15s/it]  BraTS20_Training_189: Dice=0.9475 (ET=0.9332, TC=0.9571, WT=0.9523) HD95_ET=1.00
# Evaluating:  95% 90/95 [13:47<00:45,  9.13s/it]  BraTS20_Training_072: Dice=0.8543 (ET=0.8667, TC=0.9356, WT=0.7605) HD95_ET=1.00
# Evaluating:  96% 91/95 [13:56<00:36,  9.15s/it]  BraTS20_Training_107: Dice=0.9189 (ET=0.9273, TC=0.9316, WT=0.8977) HD95_ET=1.00
# Evaluating:  97% 92/95 [14:05<00:27,  9.09s/it]  BraTS20_Training_271: Dice=0.6294 (ET=0.1481, TC=0.8472, WT=0.8930) HD95_ET=11.44
# Evaluating:  98% 93/95 [14:13<00:17,  9.00s/it]  BraTS20_Training_349: Dice=0.9393 (ET=0.9027, TC=0.9626, WT=0.9525) HD95_ET=1.00
# Evaluating:  99% 94/95 [14:23<00:09,  9.08s/it]  BraTS20_Training_103: Dice=0.9098 (ET=0.8717, TC=0.9446, WT=0.9129) HD95_ET=1.00
# Evaluating: 100% 95/95 [14:32<00:00,  9.18s/it]
#
# ============================================================
# Results: test split, 95 cases, text=True
# ============================================================
#   dice_ET: 0.7640 +/- 0.2116
#   dice_TC: 0.8473 +/- 0.1447
#   dice_WT: 0.8850 +/- 0.0869
#   dice_mean: 0.8321 +/- 0.1133
#   hd95_ET: 4.65 +/- 13.22
#   hd95_TC: 3.85 +/- 12.34
#   hd95_WT: 3.35 +/- 12.92
# ============================================================
#
# ============================================================
# Evaluation: Without Text (fusion bypassed)
# ============================================================
# Loading weights: 100% 199/199 [00:00<00:00, 945.63it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loaded checkpoint: epoch=174, best_dice=0.8808841492448535
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# TextBraTS test: 95 samples
#
# Evaluating 95 cases (test split)
# Sliding window: patch=(128, 128, 128), overlap=0.5, text=False
#
# Evaluating:   0% 0/95 [00:00<?, ?it/s]  BraTS20_Training_328: Dice=0.5933 (ET=0.1889, TC=0.6604, WT=0.9307) HD95_ET=51.31
# Evaluating:   1% 1/95 [00:09<14:40,  9.37s/it]  BraTS20_Training_028: Dice=0.7485 (ET=0.5999, TC=0.8344, WT=0.8110) HD95_ET=2.00
# Evaluating:   2% 2/95 [00:17<13:42,  8.84s/it]  BraTS20_Training_289: Dice=0.5004 (ET=0.0000, TC=0.5842, WT=0.9169) HD95_ET=nan
# Evaluating:   3% 3/95 [00:25<12:42,  8.28s/it]  BraTS20_Training_231: Dice=0.9342 (ET=0.9169, TC=0.9303, WT=0.9554) HD95_ET=1.00
# Evaluating:  95% 90/95 [13:09<00:43,  8.77s/it]  BraTS20_Training_072: Dice=0.8522 (ET=0.8669, TC=0.9378, WT=0.7519) HD95_ET=1.00
# Evaluating:  96% 91/95 [13:18<00:35,  8.89s/it]  BraTS20_Training_107: Dice=0.9160 (ET=0.9271, TC=0.9297, WT=0.8912) HD95_ET=1.00
# Evaluating:  97% 92/95 [13:27<00:26,  8.84s/it]  BraTS20_Training_271: Dice=0.6470 (ET=0.1333, TC=0.9112, WT=0.8965) HD95_ET=11.41
# Evaluating:  98% 93/95 [13:36<00:17,  8.83s/it]  BraTS20_Training_349: Dice=0.9368 (ET=0.9012, TC=0.9624, WT=0.9469) HD95_ET=1.00
# Evaluating:  99% 94/95 [13:45<00:08,  8.88s/it]  BraTS20_Training_103: Dice=0.9074 (ET=0.8697, TC=0.9438, WT=0.9086) HD95_ET=1.00
# Evaluating: 100% 95/95 [13:54<00:00,  8.78s/it]
#
# ============================================================
# Results: test split, 95 cases, text=False
# ============================================================
#   dice_ET: 0.7612 +/- 0.2157
#   dice_TC: 0.8482 +/- 0.1524
#   dice_WT: 0.8854 +/- 0.0858
#   dice_mean: 0.8316 +/- 0.1175
#   hd95_ET: 4.65 +/- 13.35
#   hd95_TC: 3.87 +/- 12.32
#   hd95_WT: 3.37 +/- 13.00
# ============================================================

# %% [markdown]
# ## 6. Results Summary & Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fill in results after training complete
# Format: [ET, TC, WT, Mean]
results = {
    "v4.1 no-text (bypass)": {
        "dice": [0.7679, 0.8415, 0.8860, 0.8318],
        "label": "v4.1 no-text"
    },
    "v4.1 with-text (MultiScale)": {
        "dice": [0.7663, 0.8411, 0.8875, 0.8316],
        "label": "v4.1 with-text"
    },
    "v4.2 with-text (FG-Contrastive)": {
        "dice": [0.0, 0.0, 0.0, 0.0],  # FILL AFTER EVAL
        "label": "v4.2 with-text"
    },
}

regions = ["ET", "TC", "WT", "Mean"]
x = np.arange(len(regions))
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))
for i, (name, data) in enumerate(results.items()):
    bars = ax.bar(x + i * width, data["dice"], width, label=data["label"])
    for bar, val in zip(bars, data["dice"]):
        if val > 0:
            ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 0.01,
                    f'{val:.1%}', ha='center', va='bottom', fontsize=8)

ax.set_ylabel('Dice Score')
ax.set_title('TextMamba3D: v4.1 vs v4.2 (ForegroundContrastiveLoss)')
ax.set_xticks(x + width)
ax.set_xticklabels(regions)
ax.legend()
ax.set_ylim(0, 1.0)
ax.axhline(y=0.853, color='r', linestyle='--', alpha=0.5, label='SOTA (85.3%)')
plt.tight_layout()
plt.savefig("results_comparison_v42.png", dpi=150)
plt.show()

print("Fill in v4.2 Dice values after evaluation!")
# Out:
# Fill in v4.2 Dice values after evaluation!

# %% [markdown]
# ## 7. TensorBoard (Optional)

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# %% [markdown]
# ## 8. Resume Training (After Colab Disconnect)
#
# If Colab disconnects mid-training, run this cell to resume from the last checkpoint saved to Drive.

# %%
# Resume from Drive checkpoint after Colab disconnect
os.chdir(REPO_DIR)
os.environ["DRIVE_CKPT_DIR"] = DRIVE_CKPT

resume_ckpt = os.path.join(DRIVE_CKPT, "last.pth")
if os.path.exists(resume_ckpt):
    print(f"Resuming from {resume_ckpt}")
    # !python train.py \
        --config configs/textbrats_a100.yaml \
        --resume "{resume_ckpt}" \
        --no-text-ratio 0.15 \
        --grad-accum 1

    sync_checkpoints_to_drive()

    best_ckpt = os.path.join(DRIVE_CKPT, "best_v4.2.pth")
    local_best = os.path.join(REPO_DIR, "checkpoints/best.pth")
    if os.path.exists(local_best):
        shutil.copy2(local_best, best_ckpt)
        print(f"Best checkpoint saved: {best_ckpt}")
else:
    print(f"No checkpoint found at {resume_ckpt}")
    print("Run the training cell (Section 4) first.")
# Out:
# Resuming from /content/drive/MyDrive/TextMamba3D/checkpoints/last.pth
# 2026-03-13 17:10:15.382836: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-13 17:10:15.400722: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773421815.422705  116388 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773421815.429921  116388 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773421815.448247  116388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773421815.448275  116388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773421815.448278  116388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773421815.448281  116388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-13 17:10:15.453081: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
# Mixed precision (AMP): True
# No-text training ratio: 0.15
# Gradient accumulation: 1
# Loading PubMedBERT tokenizer: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# Using TextBraTS dataset (expert-annotated text)
# TextBraTS train: 219 samples
# TextBraTS val: 54 samples
# Train samples: 219, Val samples: 54
# Gradient checkpointing: ENABLED (saves ~30-50% GPU memory)
# Deep supervision: ENABLED (aux heads at intermediate decoder stages)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 1011.01it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Trainable parameters: 36,130,208
# Class weights: [0.25, 3.0, 1.0, 4.0]
# Resumed from epoch 177
# Epoch 177: 100% 55/55 [01:16<00:00,  1.40s/it, loss=0.4952, text=Y]
# Epoch 177: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.16it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.22it/s]
# Epoch 177: train_loss=0.6857
#   With text:    val_loss=0.3990, val_dice=0.8799
#   Without text: val_loss=0.3900, val_dice=0.8792
#   Contrastive weight: 0.0500
# Epoch 178: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.6253, text=Y]
# Epoch 178: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.23it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.30it/s]
# Epoch 178: train_loss=0.6938
#   With text:    val_loss=0.3979, val_dice=0.8813
#   Without text: val_loss=0.3878, val_dice=0.8807
#   Contrastive weight: 0.0500
#   -> New best (with-text): 0.8813
# Epoch 179: 100% 55/55 [01:07<00:00,  1.23s/it, loss=0.5394, text=Y]
# Epoch 179: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.16it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 179: train_loss=0.6846
#   With text:    val_loss=0.4010, val_dice=0.8800
#   Without text: val_loss=0.3890, val_dice=0.8802
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 179)
# Epoch 180: 100% 55/55 [01:16<00:00,  1.39s/it, loss=0.4691, text=Y]
# Epoch 180: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.12it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 180: train_loss=0.6721
#   With text:    val_loss=0.4020, val_dice=0.8809
#   Without text: val_loss=0.3909, val_dice=0.8804
#   Contrastive weight: 0.0500
# Epoch 181: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.5702, text=Y]
# Epoch 181: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.23it/s]
# Epoch 181: train_loss=0.6565
#   With text:    val_loss=0.4027, val_dice=0.8797
#   Without text: val_loss=0.3902, val_dice=0.8801
#   Contrastive weight: 0.0500
# Epoch 182: 100% 55/55 [01:09<00:00,  1.26s/it, loss=1.1576, text=Y]
# Epoch 182: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 182: train_loss=0.6678
#   With text:    val_loss=0.4022, val_dice=0.8803
#   Without text: val_loss=0.3889, val_dice=0.8808
#   Contrastive weight: 0.0500
# Epoch 183: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.5991, text=Y]
# Epoch 183: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 183: train_loss=0.6895
#   With text:    val_loss=0.4019, val_dice=0.8803
#   Without text: val_loss=0.3898, val_dice=0.8806
#   Contrastive weight: 0.0500
# Epoch 184: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.5886, text=N]
# Epoch 184: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.27it/s]
# Epoch 184: train_loss=0.6641
#   With text:    val_loss=0.4009, val_dice=0.8803
#   Without text: val_loss=0.3890, val_dice=0.8805
#   Contrastive weight: 0.0500
# Epoch 185: 100% 55/55 [01:12<00:00,  1.33s/it, loss=0.7608, text=Y]
# Epoch 185: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.24it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.25it/s]
# Epoch 185: train_loss=0.6640
#   With text:    val_loss=0.4007, val_dice=0.8796
#   Without text: val_loss=0.3881, val_dice=0.8803
#   Contrastive weight: 0.0500
# Epoch 186: 100% 55/55 [01:09<00:00,  1.26s/it, loss=0.8030, text=Y]
# Epoch 186: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 186: train_loss=0.6659
#   With text:    val_loss=0.3997, val_dice=0.8797
#   Without text: val_loss=0.3870, val_dice=0.8805
#   Contrastive weight: 0.0500
# Epoch 187: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.8658, text=Y]
# Epoch 187: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 187: train_loss=0.6753
#   With text:    val_loss=0.3995, val_dice=0.8795
#   Without text: val_loss=0.3868, val_dice=0.8805
#   Contrastive weight: 0.0500
# Epoch 188: 100% 55/55 [01:09<00:00,  1.27s/it, loss=1.2414, text=Y]
# Epoch 188: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.26it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 188: train_loss=0.6796
#   With text:    val_loss=0.3996, val_dice=0.8799
#   Without text: val_loss=0.3871, val_dice=0.8808
#   Contrastive weight: 0.0500
# Epoch 189: 100% 55/55 [01:07<00:00,  1.23s/it, loss=0.5791, text=N]
# Epoch 189: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 189: train_loss=0.6306
#   With text:    val_loss=0.3999, val_dice=0.8802
#   Without text: val_loss=0.3876, val_dice=0.8811
#   Contrastive weight: 0.0500
#   -> New best (no-text): 0.8811
#   -> Synced checkpoints to Drive (epoch 189)
# Epoch 190: 100% 55/55 [01:11<00:00,  1.30s/it, loss=0.6318, text=Y]
# Epoch 190: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:12<00:00,  1.15it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.25it/s]
# Epoch 190: train_loss=0.6325
#   With text:    val_loss=0.3998, val_dice=0.8802
#   Without text: val_loss=0.3876, val_dice=0.8811
#   Contrastive weight: 0.0500
# Epoch 191: 100% 55/55 [01:07<00:00,  1.23s/it, loss=0.7800, text=Y]
# Epoch 191: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.29it/s]
# Epoch 191: train_loss=0.6482
#   With text:    val_loss=0.4003, val_dice=0.8802
#   Without text: val_loss=0.3880, val_dice=0.8810
#   Contrastive weight: 0.0500
# Epoch 192: 100% 55/55 [01:10<00:00,  1.29s/it, loss=0.5288, text=Y]
# Epoch 192: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.20it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 192: train_loss=0.6881
#   With text:    val_loss=0.4000, val_dice=0.8799
#   Without text: val_loss=0.3877, val_dice=0.8808
#   Contrastive weight: 0.0500
# Epoch 193: 100% 55/55 [01:07<00:00,  1.23s/it, loss=0.4538, text=Y]
# Epoch 193: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.28it/s]
# Epoch 193: train_loss=0.6640
#   With text:    val_loss=0.3997, val_dice=0.8796
#   Without text: val_loss=0.3872, val_dice=0.8805
#   Contrastive weight: 0.0500
# Epoch 194: 100% 55/55 [01:06<00:00,  1.22s/it, loss=0.5991, text=Y]
# Epoch 194: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.25it/s]
# Epoch 194: train_loss=0.6443
#   With text:    val_loss=0.3995, val_dice=0.8797
#   Without text: val_loss=0.3870, val_dice=0.8806
#   Contrastive weight: 0.0500
# Epoch 195: 100% 55/55 [01:09<00:00,  1.27s/it, loss=0.5380, text=Y]
# Epoch 195: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.18it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.26it/s]
# Epoch 195: train_loss=0.6687
#   With text:    val_loss=0.3994, val_dice=0.8796
#   Without text: val_loss=0.3868, val_dice=0.8806
#   Contrastive weight: 0.0500
# Epoch 196: 100% 55/55 [01:14<00:00,  1.35s/it, loss=0.7310, text=N]
# Epoch 196: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.21it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 196: train_loss=0.6461
#   With text:    val_loss=0.3994, val_dice=0.8795
#   Without text: val_loss=0.3868, val_dice=0.8805
#   Contrastive weight: 0.0500
# Epoch 197: 100% 55/55 [01:13<00:00,  1.33s/it, loss=0.8214, text=Y]
# Epoch 197: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.23it/s]
# Epoch 197: train_loss=0.6542
#   With text:    val_loss=0.3994, val_dice=0.8796
#   Without text: val_loss=0.3868, val_dice=0.8806
#   Contrastive weight: 0.0500
# Epoch 198: 100% 55/55 [01:06<00:00,  1.21s/it, loss=0.5798, text=Y]
# Epoch 198: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.25it/s]
# Validating (no-text): 100% 14/14 [00:10<00:00,  1.30it/s]
# Epoch 198: train_loss=0.6625
#   With text:    val_loss=0.3994, val_dice=0.8796
#   Without text: val_loss=0.3868, val_dice=0.8806
#   Contrastive weight: 0.0500
# Epoch 199: 100% 55/55 [01:13<00:00,  1.33s/it, loss=0.7860, text=Y]
# Epoch 199: NaN/Inf skipped batches=0
# Validating: 100% 14/14 [00:11<00:00,  1.19it/s]
# Validating (no-text): 100% 14/14 [00:11<00:00,  1.27it/s]
# Epoch 199: train_loss=0.6560
#   With text:    val_loss=0.3995, val_dice=0.8796
#   Without text: val_loss=0.3869, val_dice=0.8806
#   Contrastive weight: 0.0500
#   -> Synced checkpoints to Drive (epoch 199)
#
# Training complete!
# Best Dice (with text): 0.8813
# Best Dice (no text):   0.8811
# Synced checkpoints to /content/drive/MyDrive/TextMamba3D/checkpoints
# Best checkpoint saved: /content/drive/MyDrive/TextMamba3D/checkpoints/best_v4.2.pth
